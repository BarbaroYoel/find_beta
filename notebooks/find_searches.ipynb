# %% [markdown]
# # Find Beta: Búsquedas
#
# <div style="text-align: center;">
#     <img src="../resources/find_logo.png" alt="Descripción de la imagen" style="width: 30%;"/>
# </div>
#
# Este notebook está diseñado para explorar las capacidades de búsqueda de la aplicación *Find Beta*. Con esta herramienta, puedes buscar restaurantes y bares según varios criterios, como:
#
# - Municipio.
# - Platos disponibles.
# - Horarios.
# - Servicios ofrecidos.
# - Rango de precios promedio.
#
# Nuestro objetivo es ofrecer una experiencia clara y sencilla para ayudarte a encontrar los mejores lugares de La Habana según tus necesidades.
#
# ---
#
#
# ## Imagina que estás buscando:
#
# 1. Un lugar cercano donde cenar pizza esta noche.
# 2. El sitio más económico para disfrutar de un mojito.
# 3. Un restaurante abierto en Plaza de la Revolución que sirva comida criolla.
#
# Con Fine Beta, estas tareas se simplifican enormemente gracias a sus funcionalidades de búsqueda personalizables.
#
# ---
#
# ## Carga de las funciones necesarias
#
# Para empezar, cargaremos las funciones esenciales para procesar los datos y realizar las búsquedas.
#
# ---

# %%
import sys
import os

parent_directory = os.path.dirname(os.getcwd())
folder_path = os.path.join(parent_directory, "app_functions")
sys.path.append(folder_path)

import search as sr 
import utils as utl

df = utl.create_data_frame_establishments()

# %% [markdown]
# ---
#
# ## Explorando la función `generic_search`
#
# La función `generic_search` es el corazón de las capacidades de búsqueda de nuestra aplicación. Su flexibilidad permite filtrar los datos según diversos criterios, adaptándose a tus necesidades específicas.
#
# ### Definición
#
# ```python
#
#  def generic_search(df, name=None, municipality=None, day=None, time=None,
#                     owner_type=None, specialty=None, establishment_type=None,
#                     min_rating=None, services=None, payment_methods=None,
#                     dish=None, dish_max_price=None, max_price=None):
# ```
#
# ### Parámetros
# | Parámetro | Tipo| Descripción|
# |-----------------------|-------------------|-----------------------------------------------------------------------------|
# | `df`                 | `pd.DataFrame`   | DataFrame que contiene la información de los restaurantes y bares.         |
# | `name`               | `str`, opcional  | Nombre del restaurante o bar.                                              |
# | `municipality`       | `str`, opcional  | Municipio donde se encuentra el establecimiento.                           |
# | `day`                | `str`, opcional  | Día de la semana para verificar horarios.                                  |
# | `time`               | `str`, opcional  | Hora en formato de 24 horas (e.g., "2000").                                |
# | `owner_type`         | `str`, opcional  | Tipo de propietario ("Privado" o "Estatal").                         |
# | `specialty`          | `str`, opcional  | Especialidad del establecimiento (e.g., "Comida Italiana","Comida Cubana").                |
# | `establishment_type` | `str`, opcional  | Tipo de establecimiento (e.g.,"Bar-Restaurante", "Restaurante" o "Bar").                     |
# | `min_rating`         | `float`, opcional| Calificación mínima requerida.                                             |
# | `services`           | `list`, opcional | Lista de servicios ofrecidos (["parking", "power plant","delivery","power plant"]).               |
# | `payment_methods`    | `list`, opcional | Métodos de pago aceptados (e.g., `["cup", "usd"]`).               |
# | `dish`               | `str`, opcional  | Nombre del plato.                                                          |
# | `dish_max_price`     | `float`, opcional| Precio máximo para el plato especificado.                                  |
# | `average_price`          | `float`, opcional| Precio promedio máximo del menú.                                           |
#
#
#
# ### Retorno
#
# Un DataFrame con los resultados que cumplen los criterios especificados.
#
# ### Ejemplos de uso
#
# #### Ejemplo 1: Búsqueda por municipio

# %%
search=sr.generic_search(df,municipality="ce")
search
# Out:
#   municipality                 name  \
# 0           ce        Brutal Habana
# 1           ce            El Batazo
# 2           ce            El Rápido
# 3           ce     Jorgito's Pizzas
# 4           ce   La Barrita Onbazar
# 5           ce  La Casona del Cerro
# 6           ce              La Lola
# 7           ce         Leyendhabana
# 8           ce            Rico Rico
# 9           ce           Shapuseros
#
#                                              address  \
# 0  Infanta esquina Calle Universidad, Cerro, La H...
# 1           Primelles 356 entre Santa Teresa y Daois
# 2          Cruz del Pader entre Pedrosa y Amenidares
# 3             Pedroso entre Infanta y Cruz del Pader
# 4             Amenida entre Cruz del Pader e Infanta
# 5          Calzada del Cerro entre Alzobispo y Peñón
# 6      Calle Ayestarán entre San Pablo y Pedro Pérez
# 7  Calle Santa Rosa No. 217 e/ Infanta y Cruz del...
# 8  Calle Ayestarán entre Perfecto Lacoste y Arang...
# 9  Calzada de Ayestarán entre San Pedro y Ayuntam...
#
#                                             contacts  \
# 0  {'phone': ['050989151'], 'website': None, 'fac...
# 1  {'phone': ['+53 58050408'], 'website': None, '...
# 2  {'phone': [], 'website': None, 'facebook': Non...
# 3  {'phone': ['+53 54031349', '78780156'], 'websi...
# 4  {'phone': ['+53 54494741'], 'website': 'labarr...
# 5  {'phone': [], 'website': None, 'facebook': Non...
# 6  {'phone': ['+53 53654726'], 'website': None, '...
# 7  {'phone': ['78781332'], 'website': 'leyendhaba...
# 8  {'phone': ['78701632'], 'website': None, 'face...
# 9  {'phone': [], 'website': None, 'facebook': Non...
#
#                                ratings    owner             type  \
# 0                      {'google': 4.0}  Privado              Bar
# 1                                   {}  Privado  Bar-Restaurante
# 2                                   {}  Privado      Restaurante
# 3                        {'google': 4}  Privado      Restaurante
# 4                                   {}  Privado  Bar-Restaurante
# 5                                   {}  Privado      Restaurante
# 6                                   {}  Privado              Bar
# 7  {'google': 4.6, 'tripadvisor': 4.5}  Privado  Bar-Restaurante
# 8                      {'google': 2.4}  Privado      Restaurante
# 9                                   {}  Privado      Restaurante
#
#          specialty                                              hours  \
# 0   Hamburguesería  {'monday': '1200_0000', 'tuesday': '1200_0000'...
# 1         Pizzeria  {'monday': '1100_2200', 'tuesday': '1100_2200'...
# 2            Tapas  {'monday': '0730_1930', 'tuesday': '0730_1930'...
# 3         Pizzeria  {'monday': '1100_2300', 'tuesday': '1100_2300'...
# 4         Pizzeria  {'monday': '0900_2300', 'tuesday': '0900_2300'...
# 5   Comida Criolla  {'monday': '1000_2200', 'tuesday': '1000_2200'...
# 6       Cocteleria  {'monday': '1400_0200', 'tuesday': '1400_0200'...
# 7  Comida Caribeña  {'monday': '1200_2300', 'tuesday': '1200_2300'...
# 8  Comida Italiana  {'monday': '0900_2300', 'tuesday': '0900_2300'...
# 9     Hamburgusera  {'monday': '0900_2100', 'tuesday': '0900_2100'...
#
#                                             services         payment_methods  \
# 0  {'parking': False, 'reservations': False, 'del...                   [cup]
# 1  {'parking': False, 'reservations': False, 'del...  [cup, usd, mlc, zelle]
# 2  {'parking': False, 'reservations': False, 'del...                   [cup]
# 3  {'parking': False, 'reservations': False, 'del...         [cup, usd, mlc]
# 4  {'parking': True, 'reservations': True, 'deliv...         [cup, usd, mlc]
# 5  {'parking': False, 'reservations': False, 'del...         [cup, usd, mlc]
# 6  {'parking': True, 'reservations': True, 'deliv...         [cup, mlc, usd]
# 7  {'parking': True, 'reservations': True, 'deliv...              [usd, eur]
# 8  {'parking': True, 'reservations': False, 'deli...                   [cup]
# 9  {'parking': False, 'reservations': False, 'del...                   [cup]
#
#                                                 menu plus
# 0  {'breakfasts': {}, 'starters': {'Papas Fritas ...  NaN
# 1  {'breakfasts': {}, 'starters': {}, 'main_cours...  NaN
# 2  {'breakfasts': {}, 'starters': {'Croquetas': 3...  NaN
# 3  {'breakfasts': {}, 'starters': {}, 'main_cours...  NaN
# 4  {'breakfasts': {}, 'starters': {'Tostones rell...  NaN
# 5  {'breakfasts': {}, 'starters': {}, 'main_cours...  NaN
# 6  {'breakfasts': {}, 'starters': {'Brusquetas': ...  NaN
# 7  {'starters': {'Tartaletas mixtas': 1235.0, 'Pu...  NaN
# 8  {'breakfasts': {}, 'starters': {'Ensalada fria...  NaN
# 9  {'breakfasts': {}, 'starters': {}, 'main_cours...   {}

# %% [markdown]
# #### Ejemplo 2: Búsqueda por municipio y horario

# %%
search=sr.generic_search(df,municipality="ce",day="saturday",time="0100")
search
# Out:
#   municipality                name  \
# 0           ce  La Barrita Onbazar
# 1           ce             La Lola
#
#                                          address  \
# 0         Amenida entre Cruz del Pader e Infanta
# 1  Calle Ayestarán entre San Pablo y Pedro Pérez
#
#                                             contacts ratings    owner  \
# 0  {'phone': ['+53 54494741'], 'website': 'labarr...      {}  Privado
# 1  {'phone': ['+53 53654726'], 'website': None, '...      {}  Privado
#
#               type   specialty  \
# 0  Bar-Restaurante    Pizzeria
# 1              Bar  Cocteleria
#
#                                                hours  \
# 0  {'monday': '0900_2300', 'tuesday': '0900_2300'...
# 1  {'monday': '1400_0200', 'tuesday': '1400_0200'...
#
#                                             services  payment_methods  \
# 0  {'parking': True, 'reservations': True, 'deliv...  [cup, usd, mlc]
# 1  {'parking': True, 'reservations': True, 'deliv...  [cup, mlc, usd]
#
#                                                 menu  plus
# 0  {'breakfasts': {}, 'starters': {'Tostones rell...   NaN
# 1  {'breakfasts': {}, 'starters': {'Brusquetas': ...   NaN

# %% [markdown]
# #### Ejemplo 3: Búsqueda por municipio , horario, plato y precio máximo del plato

# %%
search=sr.generic_search(df,municipality="ch",day="sunday",time="1300",dish="pizza",dish_max_price=500)
search
# Out:
#   municipality          name  \
# 0           ch  Fénix Dorado
# 1           ch   Infanta 560
# 2           ch   Ivonne Café
#
#                                              address  \
# 0                  Cuchillo entre San Nicolás y Rayo
# 1  latitude: 23.135420733511385, longitude: -82.3...
# 2                 San Lazaro entre Espada y Hospital
#
#                                             contacts               ratings  \
# 0  {'phone': [], 'website': None, 'facebook': Non...  {'tripadvisor': 3.5}
# 1  {'phone': None, 'website': None, 'facebook': N...                    {}
# 2  {'phone': [], 'website': None, 'facebook': Non...                    {}
#
#      owner             type        specialty  \
# 0  Privado      Restaurante     Comida China
# 1  Privado      Restaurante  Comida Italiana
# 2  Privado  Bar-Restaurante           Dulces
#
#                                                hours  \
# 0  {'monday': '1100_2300', 'tuesday': '1100_2300'...
# 1  {'monday': '0800_2200', 'tuesday': '0800_2200'...
# 2  {'monday': '0900_2200', 'tuesday': '0900_2200'...
#
#                                             services payment_methods  \
# 0  {'parking': False, 'reservations': False, 'del...              []
# 1  {'parking': False, 'reservations': False, 'del...           [cup]
# 2  {'parking': False, 'reservations': False, 'del...           [cup]
#
#                                                 menu  plus
# 0  {'breakfasts': {}, 'starters': {'Picadera Féni...   NaN
# 1  {'breakfasts': {}, 'starters': {'picadera (300...   NaN
# 2  {'breakfasts': {}, 'starters': {}, 'main_cours...   NaN

# %% [markdown]
# ---
#
# ## Espacio para interactuar con *generic_search(...)*:
#
# A continuación, te ofrecemos un espacio para que realices tus propias búsquedas. Ajusta los
# filtros según tus necesidades y descubre qué opciones te ofrece Find Beta.
#
# ---

# %%
search=sr.generic_search(df)
search
# Out:
#     municipality                      name  \
# 0             an                   Atlanta
# 1             an             Casa del Maíz
# 2             an  Comida Criolla Ocho Vías
# 3             an               Don Burguer
# 4             an               Doña Almira
# ..           ...                       ...
# 200           sm                El Tráfico
# 201           sm                     GaraG
# 202           sm                     KY-13
# 203           sm                La Patrona
# 204           sm          Yesterday Havana
#
#                                                address  \
# 0    Atlanta #9, entre Calzada de Porvenir y Calzad...
# 1    Avenida 1er anillo % Calzada de Managua y San ...
# 2    Avenida 1er Anillo 3km despues de San Agustin,...
# 3    Calzada de 10 de Octubre, entre  Aranguren y S...
# 4    Calle Finlay No.979 % Avenida de Los Pinos y F...
# ..                                                 ...
# 200                    Calzada de Guines entre 90 y 94
# 201           C. Guanabacoa #1214 % B y C, Los Angeles
# 202   calzada de guines #45 e/ 13 y 23 AMP. San Matias
# 203        Calzada de Guines en San Francisco de Paula
# 204                 Rita % Blanchi y Calzada de Guines
#
#                                               contacts ratings    owner  \
# 0    {'phone': ['+59694801'], 'website': None, 'fac...      {}  Privado
# 1    {'phone': ['52003758'], 'website': None, 'face...      {}  Privado
# 2    {'phone': ['+5359107933'], 'website': None, 'f...      {}  Privado
# 3    {'phone': ['+53 56073379'], 'website': None, '...      {}  Privado
# 4    {'phone': ['76472432', '52928671'], 'website':...      {}  Privado
# ..                                                 ...     ...      ...
# 200  {'phone': [], 'website': None, 'facebook': Non...      {}  Privado
# 201  {'phone': [], 'website': None, 'facebook': Non...      {}  Privado
# 202  {'phone': [], 'website': None, 'facebook': Non...      {}  Privado
# 203  {'phone': [], 'website': None, 'facebook': Non...      {}  Privado
# 204  {'phone': ['76930649'], 'website': None, 'face...      {}  Privado
#
#                 type          specialty  \
# 0        Restaurante      Comida Cubana
# 1        Restaurante      Comida Cubana
# 2        Restaurante      Comida Cubana
# 3        Restaurante  [Comida chatarra]
# 4        Restaurante      Comida Cubana
# ..               ...                ...
# 200      Restaurante       Comida Mixta
# 201  Bar-Restaurante       Comida Mixta
# 202      Restaurante       Comida Mixta
# 203      Restaurante       Comida Mixta
# 204  Bar-Restaurante       Comida Mixta
#
#                                                  hours  \
# 0    {'monday': '1000_2200', 'tuesday': '1000_2200'...
# 1    {'monday': '1000_2000', 'tuesday': '1000_2000'...
# 2    {'monday': '1100_2300', 'tuesday': '1100_2300'...
# 3    {'monday': '1000_2300', 'tuesday': '1000_2300'...
# 4    {'monday': '1200_2300', 'tuesday': '1200_2300'...
# ..                                                 ...
# 200  {'monday': '1000_2200', 'tuesday': '1000_2200'...
# 201  {'monday': '1200_0000', 'tuesday': '1200_0000'...
# 202  {'monday': '1000_2300', 'tuesday': '1000_2300'...
# 203  {'monday': None, 'tuesday': '0800_0000', 'wedn...
# 204  {'monday': '0900_2200', 'tuesday': '0900_2200'...
#
#                                               services  payment_methods  \
# 0    {'parking': True, 'reservations': False, 'deli...  [cup, usd, mlc]
# 1    {'parking': True, 'reservations': False, 'deli...            [cup]
# 2    {'parking': True, 'reservations': True, 'deliv...  [cup, usd, mlc]
# 3    {'parking': True, 'reservations': False, 'deli...  [cup, usd, mlc]
# 4    {'parking': False, 'reservations': True, 'deli...  [cup, usd, mlc]
# ..                                                 ...              ...
# 200  {'parking': None, 'reservations': True, 'deliv...            [cup]
# 201  {'parking': None, 'reservations': None, 'deliv...            [cup]
# 202  {'parking': None, 'reservations': True, 'deliv...            [cup]
# 203  {'parking': None, 'reservations': True, 'deliv...            [cup]
# 204  {'parking': False, 'reservations': False, 'del...            [cup]
#
#                                                   menu plus
# 0    {'breakfasts': {}, 'starters': {'croquetas de ...  NaN
# 1    {'breakfasts': {}, 'starters': {'Fritura de Ma...  NaN
# 2    {'breakfasts': {}, 'starters': {'Croquetas de ...  NaN
# 3    {'breakfasts': {}, 'starters': {'ENSALADA FRÍA...  NaN
# 4    {'breakfasts': {}, 'starters': {'Tostones rell...  NaN
# ..                                                 ...  ...
# 200  {'breakfasts': {}, 'starters': {}, 'main_cours...  NaN
# 201  {'breakfasts': {}, 'starters': {'Picadera Gara...  NaN
# 202  {'breakfasts': {}, 'starters': {'croquetas de ...  NaN
# 203  {'breakfasts': {}, 'starters': {}, 'main_cours...  NaN
# 204  {'breakfasts': {}, 'starters': {'Picadera Yest...  NaN
#
# [205 rows x 13 columns]

# %% [markdown]
# ---
# ## Navegación entre Notebooks
# Para explorar las funcionalidades de **Find Beta**, te invitamos a visitar los siguientes notebooks:
#
# - [Notebook Introductorio](./introduction_app.ipynb): Te introduce en Find Beta
# - [Notebook de Análisis](./find_analysis.ipynb): Descubre patrones y tendencias en los datos.
#
# ---
